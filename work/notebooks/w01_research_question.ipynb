# %% [markdown]
# <a href="https://colab.research.google.com/github/cognitivefairy/Machine-Learning-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cognitivefairy/Machine-Learning-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Research Question: Which observable search and content signals show the strongest
# association with content performance in the anonymized FlyRank dataset?
#
# I chose the Ranking Signal Analysis lane because it focuses on understanding relationships
# between observable signals rather than building a prediction system. As someone with a
# psychology background who plans to pursue graduate studies in cognitive science, I am
# interested in learning how to formulate research questions, analyze large observational
# datasets, and interpret statistical relationships responsibly. This lane will allow me
# to develop quantitative research skills while learning Python-based data analysis and
# machine learning methods.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# This project aims to improve decisions about which content signals deserve further
# investigation when evaluating content performance. The primary users are analysts
# and content teams who use evidence from the data to prioritize future analysis or
# review. A wrong conclusion could lead people to focus on unimportant signals while
# overlooking more informative ones, resulting in wasted effort or poor decision-making.
# Because this is an observational analysis, the findings should be treated as evidence
# for further investigation rather than proof of cause-and-effect.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains 30,000 anonymized web pages, providing a sufficiently large sample for exploratory analysis. Approximately 54.2% of the pages are labeled as declining based on their recent trend direction, giving a reasonably balanced outcome for comparing ranking signals. The dataset also includes several observable variables such as impressions over the last 90 days, average search position, click-through rate (CTR), content age, word count, and days since the last updatew hich provide multiple measurable signals for investigating how content characteristics are associated with search performance. These initial observations suggest the dataset is well suited for exploring relationships between ranking signals and performance outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["is_declining_label"] = (
    df["trend_direction"]
      .str.lower()
      .eq("down")
      .astype(int)
)

print(f"Number of pages: {len(df):,}")
print(f"Declining rate: {df['is_declining_label'].mean():.3f}")
print(f"Number of columns: {df.shape[1]}")

print("\nColumns:")
print(df.columns.tolist())

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project can identify observed associations between measurable content signals and performance outcomes. It may suggest which variables are more strongly associated with visibility, engagement, or ranking trends and can provide evidence to support decision-making. However, the analysis cannot demonstrate causal relationships, prove how Google's ranking systems work, or guarantee that changing a particular feature will improve performance. Any findings should be interpreted as observational and directional rather than causal.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
